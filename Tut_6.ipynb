# %%
from keras.utils import load_img
import matplotlib.pyplot as plt

img = load_img('/content/1_Gammar 2021_1_2021_06_03-13-19-23-879.PNG')  # replace with your image filename
plt.imshow(img)
plt.title("Insect Image")
plt.axis('off')
plt.show()

# %%
# Task 1_2: Convert the image to numpy array
from keras.utils import load_img, img_to_array, array_to_img

# load the image using the previously used image path
img_path = '/content/1_Gammar 2021_1_2021_06_03-13-19-23-879.PNG'
img = load_img(img_path)
print(type(img))

# convert to numpy array
img_array = img_to_array(img)
print(img_array.dtype)
print(img_array.shape)

# convert back to image
img_pil = array_to_img(img_array)
print(type(img_pil))
# Out:
# <class 'PIL.PngImagePlugin.PngImageFile'>
# float32
# (464, 464, 3)
# <class 'PIL.Image.Image'>

# %%
from keras.utils import load_img, img_to_array
import numpy as np

img = load_img('your_insect_image.jpg')
img_array = img_to_array(img)
print("Shape:", img_array.shape)
print("Data type:", img_array.dtype)
print(img_array)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_3019/312207636.py in <cell line: 0>()
#       2 import numpy as np
#       3
# ----> 4 img = load_img('your_insect_image.jpg')
#       5 img_array = img_to_array(img)
#       6 print("Shape:", img_array.shape)
#
# /usr/local/lib/python3.12/dist-packages/keras/src/utils/image_utils.py in load_img(path, color_mode, target_size, interpolation, keep_aspect_ratio)
#     245         if isinstance(path, pathlib.Path):
#     246             path = str(path.resolve())
# --> 247         with open(path, "rb") as f:
#     248             img = pil_image.open(io.BytesIO(f.read()))
#     249     else:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'your_insect_image.jpg'

# %%
from keras.utils import load_img, img_to_array

img = load_img('/content/1_Gammar 2021_1_2021_06_03-13-19-23-879.PNG')
img_array = img_to_array(img)
print('Shape:', img_array.shape)
print('Data type:', img_array.dtype)
print('Min value:', img_array.min(), 'Max value:', img_array.max())
print(img_array)
# Out:
# Shape: (464, 464, 3)
# Data type: float32
# Min value: 0.0 Max value: 255.0
# [[[ 39.  76. 128.]
#   [ 38.  83. 128.]
#   [ 37.  74. 122.]
#   ...
#   [ 39.  74. 123.]
#   [ 41.  72. 120.]
#   [ 41.  72. 117.]]
#
#  [[ 41.  84. 127.]
#   [ 39.  91. 127.]
#   [ 38.  76. 122.]
#   ...
#   [ 40.  73. 121.]
#   [ 41.  73. 120.]
#   [ 41.  75. 120.]]
#
#  [[ 40.  78. 127.]
#   [ 39.  83. 127.]
#   [ 38.  72. 122.]
#   ...
#   [ 39.  73. 120.]
#   [ 41.  71. 121.]
#   [ 41.  72. 122.]]
#
#  ...
#
#  [[100. 134.  78.]
#   [ 50.  85.  78.]
#   [  0.  70. 101.]
#   ...
#   [ 40.  85. 131.]
#   [ 39.  84. 133.]
#   [ 39.  91. 136.]]
#
#  [[102. 186.  69.]
#   [ 51. 106.  69.]
#   [  1.  63.  98.]
#   ...
#   [ 41.  85. 130.]
#   [ 40.  79. 133.]
#   [ 40.  83. 137.]]
#
#  [[103. 138.  75.]
#   [ 53.  89.  75.]
#   [  3.  72. 100.]
#   ...
#   [ 42.  85. 131.]
#   [ 41.  82. 134.]
#   [ 41.  84. 136.]]]

# %%
from keras.utils import load_img, img_to_array
import matplotlib.pyplot as plt

img = load_img('/content/1_Gammar 2021_1_2021_06_03-13-19-23-879.PNG', color_mode='grayscale')
img.save('grayscale_insect.jpg')

reloaded = load_img('grayscale_insect.jpg', color_mode='grayscale')
plt.imshow(img_to_array(reloaded).squeeze(), cmap='gray')
plt.title('Grayscale Image')
plt.axis('off')
plt.show()

# %%
from keras.datasets import mnist

(X_train, y_train), (X_test, y_test) = mnist.load_data()
print("Training data shape:", X_train.shape)
print("Test data shape:", X_test.shape)
print("Training labels shape:", y_train.shape)
print("Min pixel value:", X_train.min(), "Max:", X_train.max())
# Out:
# ...
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Training data shape: (60000, 28, 28)
# Test data shape: (10000, 28, 28)
# Training labels shape: (60000,)
# Min pixel value: 0 Max: 255

# %%
from keras.datasets import mnist

(X_train, y_train), (X_test, y_test) = mnist.load_data()
X_train_norm = X_train / 255.0
X_test_norm = X_test / 255.0

print("Min:", X_train_norm.min(), "Max:", X_train_norm.max())
print("Shape:", X_train_norm.shape)
# Out:
# Min: 0.0 Max: 1.0
# Shape: (60000, 28, 28)

# %%
from keras.datasets import mnist
import numpy as np

(X_train, y_train), (X_test, y_test) = mnist.load_data()
mean = X_train.mean()
X_train_centered = X_train - mean
X_test_centered = X_test - mean

print("Mean before:", X_train.mean())
print("Mean after centering:", X_train_centered.mean())
# Out:
# Mean before: 33.318421449829934
# Mean after centering: 9.893771063189535e-15

# %%
from keras.datasets import mnist
import numpy as np

(X_train, y_train), (X_test, y_test) = mnist.load_data()
mean = X_train.mean()
std = X_train.std()
X_train_std = (X_train - mean) / std
X_test_std = (X_test - mean) / std

print("Mean:", X_train_std.mean())
print("Std:", X_train_std.std())
# Out:
# Mean: -3.064638490070051e-17
# Std: 0.9999999999999998
